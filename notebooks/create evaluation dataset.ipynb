# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/Lucy/Google Drive/MSDS/2016Fall/DSGA1006/Data/unsupervised/trunc_clustering.csv',index_col = 0)

# %%
df.head()
# Out:
#    Unnamed: 0.1                          company_uuid         company_name  \
# 0             0  2593028d-6633-21c4-6eb0-fa483675754c              Apsiyon
# 1             1  fe57be45-36ee-ed64-289a-a06ac3f10142            Fastudent
# 3             3  a2cbba96-bddd-09a2-76a8-9926b847faea                Lydia
# 4             4  231686ac-6311-465d-d96c-267505d7824a              Owtware
# 5             5  a33c37bc-eeda-bca2-52a8-05ad191420fe  Pricebook Co., Ltd.
#
#                                company_category_list  \
# 0                                      SaaS|Software
# 1                                          Education
# 3              Apps|FinTech|Mobile Payments|Software
# 4  Cyber Security|Enterprise Software|Virtualization
# 5                                         E-Commerce
#
#                                  category_group_list  \
# 0                                           software
# 1                                          education
# ...

# %%
df.drop('Unnamed: 0.1',1,inplace = True)

# %%
df.to_csv('/Users/Lucy/Google Drive/MSDS/2016Fall/DSGA1006/Data/unsupervised/trunc_clustering.csv',index_col = 0)
# Out:
#                            company_uuid         company_name  \
# 0  2593028d-6633-21c4-6eb0-fa483675754c              Apsiyon
# 1  fe57be45-36ee-ed64-289a-a06ac3f10142            Fastudent
# 3  a2cbba96-bddd-09a2-76a8-9926b847faea                Lydia
# 4  231686ac-6311-465d-d96c-267505d7824a              Owtware
# 5  a33c37bc-eeda-bca2-52a8-05ad191420fe  Pricebook Co., Ltd.
#
#                                company_category_list  \
# 0                                      SaaS|Software
# 1                                          Education
# 3              Apps|FinTech|Mobile Payments|Software
# 4  Cyber Security|Enterprise Software|Virtualization
# 5                                         E-Commerce
#
#                                  category_group_list  \
# 0                                           software
# 1                                          education
# 3   apps|financial services|mobile|payments|software
# 4  hardware|information technology|privacy and se...
# ...
